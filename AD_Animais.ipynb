# %%
from io import BytesIO

import requests
import pandas as pd

r = requests.get('https://docs.google.com/spreadsheets/d/e/2PACX-1vS_XoGAga3pSQTaJmrADK62L8xnZnhhCRUgJ4hTlX8CrpDXi9srJRUJ8f34D0c_lYsToxGcQMxnICFB/pub?gid=1826860762&single=true&output=csv')
data = r.content

# %%
df = pd.read_csv(BytesIO(data), index_col=0)
df.head(37)
# Out:
#                       Você sabia que 475 milhões de animais silvestres morrem por ano nas rodovias brasileiras?  \
# Carimbo de data/hora
# 25/02/2022 10:08:16                                                   2
# 25/02/2022 10:35:51                                                   2
# 25/02/2022 11:19:56                                                   2
# 25/02/2022 11:40:56                                                   2
# 25/02/2022 14:51:56                                                   2
# 28/02/2022 18:46:49                                                   2
# 01/03/2022 15:38:39                                                   2
# 01/03/2022 17:17:54                                                   2
# 02/03/2022 12:18:36                                                   2
# 03/03/2022 10:07:53                                                   2
# 03/03/2022 10:22:11                                                   1
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# Você sabia que 475 milhões de animais silvestres morrem por ano nas rodovias brasileiras?
# Você já visualizou algum animal silvestre atropelado ou atravessando estradas?
# Se por acaso você enxergasse um animal ferido na estrada, você saberia para qual número ligar?
# Caso fosse mais fácil comunicar a localização desse animal, você estaria disposto(a) a informar?

# %%
df.columns = ['Sabia', 'Ja viu', 'Saberia ligar', 'Disposto']
for col in df.columns:
    print(col)
# Out:
# Sabia
# Ja viu
# Saberia ligar
# Disposto

# %%
nREGISTROS = len(df)
nREGISTROS
# Out:
# 37

# %%
counts1 = df['Ja viu'].value_counts().to_dict()
print(counts)
# Out:
# {1: 30, 2: 7}

# %%
df1 = df['Ja viu'].value_counts()
nPromotores = float(df1[1]) + float(df1[2])
nPromotores
PorcentagemPromotoes = nPromotores/nREGISTROS
PorcentagemPromotoes
# Out:
# 1.0

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

jviu = ['Não respoderam','Sim','Não']
print(sNOTA)

QTD = np.zeros(4)

for i in range(1, 3):
  QTD[i] = counts[i]

fig = go.Figure(data=[go.Pie(labels=jviu, values=QTD, textinfo='label+percent',title= 'Você já visualizou algum animal silvestre atropelado ou atravessando estradas?',
                             insidetextorientation='radial'
                            )])
fig.show()
# Out:
# ['Não respoderam', 'Sim', 'Não']
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Scatter(
    x=jviu, y=QTD,
    mode='markers',
    marker_size=[10, 20,30])
])

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.graph_objects as go

# Use `hole` to create a donut-like pie chart
fig = go.Figure(data=[go.Pie(labels=jviu, values=QTD, hole=.3)])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

fig = go.Figure([go.Bar(x=jviu, y=QTD)])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
counts2 = df['Saberia ligar'].value_counts().to_dict()
print(counts2)
# Out:
# {2: 32, 1: 5}

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

saberia = ['Não responderam','Saberia o numero','Não saberia o numero']

QTD2 = np.zeros(4)

for i in range(1, 3):
  QTD2[i] = counts2[i]

fig = go.Figure([go.Bar(x=saberia, y=QTD2)])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
